# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
from sklearn import metrics

# %%
from sklearn import metrics

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
from sklearn.linear_model import LogisticRegression

# %%
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("https://raw.githubusercontent.com/okfn/dataportals.org/master/data/portals.csv")

# %%
print(df)
# Out:
#                          name  \
# 0                   a2gov_org
# 1    acikveri-sahinbey-bel-tr
# 2            africa_open_data
# 3     ajuntament-de-tarragona
# 4       ajuntament-de-terassa
# ..                        ...
# 600           open-data-nepal
# 601                   stat-tj
# 602                dadosjusbr
# 603       bratislava-opendata
# 604       cz-prague-geoportal
#
#                                                  title  \
# 0                                  Ann Arbor, Michigan
# 1                      Açık Veri Portali - Test Yayını
# 2                                     Africa Open Data
# 3                                  Open Data Tarragona
# 4                                    Open Data Terassa
# ..                                                 ...
# 600                                    Open Data Nepal
# 601  Agency on Statistics under President of the Re...
# 602                                         DadosJusBR
# 603                        Bratislava Open Data Portal
# 604                    Geoportal of the city of Prague
#
#                                               url  \
# 0    https://www.a2gov.org/services/data-catalog/
# 1        https://acikveri.sahinbey.bel.tr/dataset
# 2                     https://africaopendata.org/
# 3                 https://opendata.tarragona.cat/
# 4                  https://opendata.terrassa.cat/
# ..                                            ...
# 600                    https://opendatanepal.com/
# 601                        https://www.stat.tj/en
# 602                       https://dadosjusbr.org/
# 603                https://opendata.bratislava.sk
# 604                https://www.geoportalpraha.cz/
#
#                                                 author  \
# 0                                    City of Ann Arbor
# 1                                             pinardag
# 2                                     Africa Open Data
# 3                              Ajuntament de Tarragona
# 4                                Ajuntament de Terassa
# ..                                                 ...
# 600                               Open Knowledge Nepal
# 601  The Statistical Agency under President of the ...
# 602  Instituto Federal de Alagoas (IFAL) in partner...
# 603  Magistrát hlavného mesta Slovenskej republiky ...
# 604          Institut plánování a rozvoje hl. m. Prahy
#
#                                              publisher      issued  \
# 0                                    City of Ann Arbor         NaN
# 1                                  SahinBey Belediyesi  2015-01-31
# 2                                     Africa Open Data         NaN
# 3                              Ajuntament de Tarragona         NaN
# 4                                Ajuntament de Terassa         NaN
# ..                                                 ...         ...
# 600                               Open Knowledge Nepal  2018-03-03
# 601  The Statistical Agency under President of the ...         NaN
# 602                       Instituto Federal de Alagoas  2018-12-31
# 603                             The city of Bratislava         NaN
# 604                                 The city of Prague         NaN
#
#     publisher_classification  \
# 0                        NaN
# 1                 Government
# 2                        NaN
# 3                 Government
# 4                 Government
# ..                       ...
# 600                Community
# 601               Government
# 602                Community
# 603               Government
# 604               Government
#
#                                            description  \
# 0          City of Ann Arbor's Open Data Catalog (USA)
# 1        The first official open data portal of Turkey
# 2    Africa's largest central repository for Govern...
# 3                                  Open Data Tarragona
# 4                                    Open Data Terassa
# ..                                                 ...
# 600  A civil society initiative to make Nepal’s dat...
# 601  The information in the Statistical Agency is p...
# 602  The portal consumes or scrapes data from sever...
# 603  Open data is information or data that is freel...
# 604  Prague geographic data, metadata search, opend...
#
#                                      tags        license_id  ...  \
# 0                       ctic unitedstates               NaN  ...
# 1                         turkey national           Unknown  ...
# 2                             ckan africa               NaN  ...
# 3                              city spain               NaN  ...
# 4                              city spain               NaN  ...
# ..                                    ...               ...  ...
# 600                            ckan nepal             cc-by  ...
# 601                 tajikistan statistics  Other (Not Open)  ...
# 602                      brazil judiciary             cc-by  ...
# 603                   bratislava slovakia               NaN  ...
# 604  czech czechia prague geoportal praha               NaN  ...
#
#                     place                location country  language  status  \
# 0     Ann Arbor, Michigan  42.2681569,-83.7312291      US        en  active
# 1        Gaziantep,Turkey    37.0587715,37.380137      TR        tr  active
# 2                  Africa    2.0000003,15.9999997      AF        en  active
# 3               Tarragona         41.1157, 1.2496      ES  ca es en  active
# 4                 Terrasa         41.5611, 2.0081      ES     es en  active
# ..                    ...                     ...     ...       ...     ...
# 600      Kathmandu, Nepal         27.7097,85.3209      NP        en  active
# 601            Tajikistan   38.5754817,68.7900625      TJ        en  active
# 602                Brazil     15.74706, -47.89593      BR        pt  active
# 603  Bratislava, Slovakia      48.14409, 17.10971      SK        sk  active
# 604       Prague, Czechia  50.0731375, 14.4176119      CZ        cs  active
#
#               metadatacreated                       generator  \
# 0    2011-06-27T18:12:57.439Z                             NaN
# 1                         NaN                             NaN
# 2    2013-03-15T07:17:26.251Z                     CKAN: 2.1.3
# 3                         NaN                             NaN
# 4                         NaN                             NaN
# ..                        ...                             ...
# 600      2022-07-01T08:37:00Z                            ckan
# 601       2022-07-17T16:49:49                             NaN
# 602      2022-07-24T22:38:06Z  Custom/in-house implementation
# 603      2023-05-04T14:22:56Z  Custom/in-house implementation
# 604      2023-05-16T14:13:00Z  Custom/in-house implementation
#
#                            api_endpoint                        api_type  \
# 0                                   NaN                             NaN
# 1                                   NaN                             NaN
# 2       https://africaopendata.org/api/                             NaN
# 3                                   NaN                             NaN
# 4                                   NaN                             NaN
# ..                                  ...                             ...
# 600       https://opendatanepal.com/api                        CKAN API
# 601                                 NaN                             NaN
# 602         https://api.dadosjusbr.org/  Custom/in-house implementation
# 603  https://opendata.bratislava.sk/api  Custom/in-house implementation
# 604                                 NaN                             NaN
#
#                    full_metadata_download
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# ..                                    ...
# 600                                   NaN
# 601                                   NaN
# 602                                   NaN
# 603                                   NaN
# 604  http://opendata.iprpraha.cz/feed.xml
#
# [605 rows x 22 columns]

# %%
df.describe()
# Out:
#              name       title                             url  \
# count         605         605                             605
# unique        605         601                             601
# top     a2gov_org  Washington  https://opendata.terrassa.cat/
# freq            1           3                               2
#
#                                 author                       publisher  \
# count                              540                             544
# unique                             499                             508
# top     African Development Bank Group  African Development Bank Group
# freq                                21                              22
#
#             issued publisher_classification  \
# count           99                      222
# unique          89                        7
# top     2013-03-01               Government
# freq             2                      193
#
#                                               description    tags license_id  \
# count                                                 553     531        290
# unique                                                550     278         43
# top     Open Data portal for the European Commission a...  canada      cc-by
# freq                                                    2      45         48
#
#         ...  place location country language  status       metadatacreated  \
# count   ...    603      582     590      596     605                   462
# unique  ...    497      495     130       78       3                   427
# top     ...  Italy      0,0      US       en  active  2018-09-12T10:58:52Z
# freq    ...      9       10     100      270     589                    30
#
#        generator                     api_endpoint  api_type  \
# count         97                               46        78
# unique        25                               46         9
# top         CKAN  https://africaopendata.org/api/  CKAN API
# freq          37                                1        38
#
#                                    full_metadata_download
# count                                                  17
# unique                                                 17
# top     https://data.qld.gov.au/api/3/action/current_p...
# freq                                                    1
#
# [4 rows x 22 columns]

# %%
size = df.size

# %%
shape = df.shape

# %%
ndim = df.ndim

# %%
print("Size:", size)
# Out:
# Size: 13310

# %%
print("Shape:", shape)
# Out:
# Shape: (605, 22)

# %%
print("Dimensions:", ndim)
# Out:
# Dimensions: 2

# %%
dataTypeSeries = df.dtypes

# %%
print("Data Type of Each Column:")
print(dataTypeSeries)
# Out:
# Data Type of Each Column:
# name                        str
# title                       str
# url                         str
# author                      str
# publisher                   str
# issued                      str
# publisher_classification    str
# description                 str
# tags                        str
# license_id                  str
# license_url                 str
# license_notes               str
# place                       str
# location                    str
# country                     str
# language                    str
# status                      str
# metadatacreated             str
# generator                   str
# api_endpoint                str
# api_type                    str
# full_metadata_download      str
# dtype: object

# %%
dummies = pd.get_dummies(df.author)

# %%
merged = pd.concat([df, dummies], axis='columns')

# %%
merged.drop(['author'], axis='columns', inplace=True)

# %%
print(merged)
# Out:
#                          name  \
# 0                   a2gov_org
# 1    acikveri-sahinbey-bel-tr
# 2            africa_open_data
# 3     ajuntament-de-tarragona
# 4       ajuntament-de-terassa
# ..                        ...
# 600           open-data-nepal
# 601                   stat-tj
# 602                dadosjusbr
# 603       bratislava-opendata
# 604       cz-prague-geoportal
#
#                                                  title  \
# 0                                  Ann Arbor, Michigan
# 1                      Açık Veri Portali - Test Yayını
# 2                                     Africa Open Data
# 3                                  Open Data Tarragona
# 4                                    Open Data Terassa
# ..                                                 ...
# 600                                    Open Data Nepal
# 601  Agency on Statistics under President of the Re...
# 602                                         DadosJusBR
# 603                        Bratislava Open Data Portal
# 604                    Geoportal of the city of Prague
#
#                                               url  \
# 0    https://www.a2gov.org/services/data-catalog/
# 1        https://acikveri.sahinbey.bel.tr/dataset
# 2                     https://africaopendata.org/
# 3                 https://opendata.tarragona.cat/
# 4                  https://opendata.terrassa.cat/
# ..                                            ...
# 600                    https://opendatanepal.com/
# 601                        https://www.stat.tj/en
# 602                       https://dadosjusbr.org/
# 603                https://opendata.bratislava.sk
# 604                https://www.geoportalpraha.cz/
#
#                                              publisher      issued  \
# 0                                    City of Ann Arbor         NaN
# 1                                  SahinBey Belediyesi  2015-01-31
# 2                                     Africa Open Data         NaN
# 3                              Ajuntament de Tarragona         NaN
# 4                                Ajuntament de Terassa         NaN
# ..                                                 ...         ...
# 600                               Open Knowledge Nepal  2018-03-03
# 601  The Statistical Agency under President of the ...         NaN
# 602                       Instituto Federal de Alagoas  2018-12-31
# 603                             The city of Bratislava         NaN
# 604                                 The city of Prague         NaN
#
#     publisher_classification  \
# 0                        NaN
# 1                 Government
# 2                        NaN
# 3                 Government
# 4                 Government
# ..                       ...
# 600                Community
# 601               Government
# 602                Community
# 603               Government
# 604               Government
#
#                                            description  \
# 0          City of Ann Arbor's Open Data Catalog (USA)
# 1        The first official open data portal of Turkey
# 2    Africa's largest central repository for Govern...
# 3                                  Open Data Tarragona
# 4                                    Open Data Terassa
# ..                                                 ...
# 600  A civil society initiative to make Nepal’s dat...
# 601  The information in the Statistical Agency is p...
# 602  The portal consumes or scrapes data from sever...
# 603  Open data is information or data that is freel...
# 604  Prague geographic data, metadata search, opend...
#
#                                      tags        license_id  \
# 0                       ctic unitedstates               NaN
# 1                         turkey national           Unknown
# 2                             ckan africa               NaN
# 3                              city spain               NaN
# 4                              city spain               NaN
# ..                                    ...               ...
# 600                            ckan nepal             cc-by
# 601                 tajikistan statistics  Other (Not Open)
# 602                      brazil judiciary             cc-by
# 603                   bratislava slovakia               NaN
# 604  czech czechia prague geoportal praha               NaN
#
#                                            license_url  ... Wyre Council  \
# 0                                                  NaN  ...        False
# 1                                                  NaN  ...        False
# 2                                                  NaN  ...        False
# 3                                                  NaN  ...        False
# 4                                                  NaN  ...        False
# ..                                                 ...  ...          ...
# 600       https://creativecommons.org/licenses/by/4.0/  ...        False
# 601                                                NaN  ...        False
# 602                                                NaN  ...        False
# 603                                                NaN  ...        False
# 604  https://www.geoportalpraha.cz/cs/licencni-podm...  ...        False
#
#     Xunta de Galicia data.go.kr data.gov.sk e-Government Center  \
# 0              False      False       False               False
# 1              False      False       False               False
# 2              False      False       False               False
# 3              False      False       False               False
# 4              False      False       False               False
# ..               ...        ...         ...                 ...
# 600            False      False       False               False
# 601            False      False       False               False
# 602            False      False       False               False
# 603            False      False       False               False
# 604            False      False       False               False
#
#     https://g0vhk.io https://garagelab.tumblr.com/ pinardag regione sardegna  \
# 0              False                         False    False            False
# 1              False                         False     True            False
# 2              False                         False    False            False
# 3              False                         False    False            False
# 4              False                         False    False            False
# ..               ...                           ...      ...              ...
# 600            False                         False    False            False
# 601            False                         False    False            False
# 602            False                         False    False            False
# 603            False                         False    False            False
# 604            False                         False    False            False
#
#     Örebro Kommun
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
# ..            ...
# 600         False
# 601         False
# 602         False
# 603         False
# 604         False
#
# [605 rows x 520 columns]
